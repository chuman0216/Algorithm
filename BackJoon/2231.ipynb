# %%
N = int(input())
print(N)
lenght = len(str(N))
print(lenght)
sum = 0
test = pow(10, 3)
# Out:
# 236
# 3

# %%
for M in range(1, N):
    sum = M
    temp = M
    for i in range(lenght, 0, -1):
        diget = temp // pow(10,i-1)
        sum += diget
        temp %= pow(10,i-1)

    if sum == N:
        print(M)
        break
else:
    print(0)
# Out:
# 226
